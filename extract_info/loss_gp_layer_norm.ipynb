# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import numpy as np
import sys
cur_folder = os.getcwd()
sys.path.append(cur_folder + "utils")
from utils import logger
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # WGAN_GP  en_es, lambda = 0.5, lr = adam 0.005, epochs =120

# %%
path_gp_ln_en_es = "data/gp_ln/en_es/log-739498.out"
line_int_ln_es= (0, 999999)  # line interval from log file
log_ln_es = logger(path_gp_ln_en_es, line_int_ln_es)
num_epochs_ln_es = log_ln_es.num_epochs
title_dic_ln_es = {}
title_dic_ln_es["title_all"] = "WGAN-GP en_es, adam, lr=0.0005, " + str(num_epochs_ln_es) + " epochs"
title_dic_ln_es["subtitle_d"] = "D loss of WGAN-GP (en_es)"
title_dic_ln_es["subtitle_g"] =  "G loss of WGAN-GP (en_es)"
save_path_ln_es = "figures/loss/gp/wgan_en_es.pdf"
log_ln_es.plot_loss_more_than_30(title_dic_ln_es, save_path_ln_es, False)

# %% [markdown]
# # WGAN_GP  en_et, lambda = 0.5, lr = adam 0.005, epochs =150

# %%
path_gp_ln_en_et = "data/gp_ln/en_et/log-739660.out"
line_int_ln_et= (0, 999999)  # line interval from log file
log_ln_et = logger(path_gp_ln_en_et, line_int_ln_es)
num_epochs_ln_et = log_ln_et.num_epochs
title_dic_ln_et = {}
title_dic_ln_et["title_all"] = "WGAN-GP en_es, adam, lr=0.0005, " + str(num_epochs_ln_et) + " epochs"
title_dic_ln_et["subtitle_d"] = "D loss of WGAN-GP (en_es)"
title_dic_ln_et["subtitle_g"] =  "G loss of WGAN-GP (en_es)"
save_path_ln_et = "figures/loss/gp/wgan_en_es.pdf"
log_ln_et.plot_loss_more_than_30(title_dic_ln_et, save_path_ln_et, False)

# %% [markdown]
# # en en

# %%
path_gp_ln_en_en = "data/gp_ln/en_en/log-777234.out"
line_int_ln_en = (0, 999999)  # line interval from log file
log_ln_en = logger(path_gp_ln_en_en, line_int_ln_en)
num_epochs_ln_en = log_ln_en.num_epochs
title_dic_ln_en = {}
title_dic_ln_en["title_all"] = "WGAN-GP en_es, adam, lr=0.0005, " + str(num_epochs_ln_en) + " epochs"
title_dic_ln_en["subtitle_d"] = "D loss of WGAN-GP (en_es)"
title_dic_ln_en["subtitle_g"] =  "G loss of WGAN-GP (en_es)"
save_path_ln_en = "figures/loss/gp/wgan_en_es.pdf"
log_ln_en.plot_loss_more_than_30(title_dic_ln_en, save_path_ln_en, False)
