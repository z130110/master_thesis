# %%
# %load_ext autoreload
# %autoreload 2
import os
import json
import matplotlib.pyplot as plt
import numpy as np
import sys
cur_folder = os.getcwd()
sys.path.append(cur_folder + "utils")
from utils import logger
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # WGAN_GP  en_es, lambda = 0.5, lr = adam 0.005, epochs =120

# %%
path_gp_ln_en_es = "data/gp_ln/en_es/log-739498.out"
line_int_ln_es= (0, 999999)  # line interval from log file
log_ln_es = logger(path_gp_ln_en_es, line_int_ln_es)
num_epochs_ln_es = log_ln_es.num_epochs
title_dic_ref_ln_es = {}
title_dic_ref_ln_es["algorithm"] = "WGAN without GP"
title_dic_ref_ln_es["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_es) + " epochs, 10 refinements"
save_ref_path_ln_es = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_en = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_es.plot_csls_cosine_with_ref(title_dic_ref_ln_es, save_ref_path_ln_es, save_or_not = False)

# %%
log_ln_es.plot_cosine_with_ref(title_dic_ref_ln_es, save_ref_path_ln_es, save_or_not = False)

# %%
log_ln_es.best_res
# Out:
# {'opt_nn@1': 34.3,
#  'opt_nn@5': 60.3,
#  'opt_nn@10': 67.3,
#  'opt_csls@1': 36.3,
#  'opt_csls@5': 64.3,
#  'opt_csls@10': 71.3,
#  'opt_cos_nn': 59.8,
#  'opt_cos_csls': 59.3,
#  'opt_ref_nn@1': 40.6,
#  'opt_ref_nn@5': 67.9,
#  'opt_ref_nn@10': 74.2,
#  'opt_ref_csls@1': 41.7,
#  'opt_ref_csls@5': 70.2,
#  'opt_ref_csls@10': 77.6,
#  'opt_ref_cos_nn': 69.2,
#  'opt_ref_csls': 69.4}

# %% [markdown]
# # WGAN_GP  en_et, lambda = 0.5, lr = adam 0.005, epochs =150

# %%
path_gp_ln_en_et = "data/gp_ln/en_et/log-739660.out"
line_int_ln_et= (0, 999999)  # line interval from log file
log_ln_et = logger(path_gp_ln_en_et, line_int_ln_et)
num_epochs_ln_et = log_ln_et.num_epochs
title_dic_ref_ln_et = {}
title_dic_ref_ln_et["algorithm"] = "WGAN-GP"
title_dic_ref_ln_et["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_et) + " epochs, 10 refinements"
save_ref_path_ln_et = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_et = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_et.plot_csls_cosine_with_ref(title_dic_ref_ln_et, save_ref_path_ln_et, save_or_not = False)

# %%
log_ln_et.best_res
# Out:
# {'opt_nn@1': 8.0,
#  'opt_nn@5': 18.4,
#  'opt_nn@10': 24.1,
#  'opt_csls@1': 11.2,
#  'opt_csls@5': 24.2,
#  'opt_csls@10': 30.9,
#  'opt_cos_nn': 47.8,
#  'opt_cos_csls': 46.0,
#  'opt_ref_nn@1': 15.5,
#  'opt_ref_nn@5': 32.1,
#  'opt_ref_nn@10': 40.4,
#  'opt_ref_csls@1': 19.0,
#  'opt_ref_csls@5': 39.6,
#  'opt_ref_csls@10': 48.5,
#  'opt_ref_cos_nn': 55.2,
#  'opt_ref_csls': 55.3}

# %% [markdown]
# # en_el

# %%
path_gp_ln_en_el = "data/gp_ln/en_el/log-739646.out"
line_int_ln_el= (0, 999999)  # line interval from log file
log_ln_el = logger(path_gp_ln_en_el, line_int_ln_el)
num_epochs_ln_el = log_ln_el.num_epochs
title_dic_ref_ln_el = {}
title_dic_ref_ln_el["algorithm"] = "WGAN-GP"
title_dic_ref_ln_el["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_el) + " epochs, 10 refinements"
save_ref_path_ln_el = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_el = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_el.plot_csls_cosine_with_ref(title_dic_ref_ln_el, save_ref_path_ln_el, save_or_not = False)

# %%
log_ln_el.best_res
# Out:
# {'opt_nn@1': 9.4,
#  'opt_nn@5': 22.9,
#  'opt_nn@10': 29.2,
#  'opt_csls@1': 13.2,
#  'opt_csls@5': 29.5,
#  'opt_csls@10': 36.6,
#  'opt_cos_nn': 50.1,
#  'opt_cos_csls': 48.3,
#  'opt_ref_nn@1': 23.0,
#  'opt_ref_nn@5': 42.8,
#  'opt_ref_nn@10': 50.5,
#  'opt_ref_csls@1': 25.3,
#  'opt_ref_csls@5': 46.3,
#  'opt_ref_csls@10': 55.3,
#  'opt_ref_cos_nn': 58.4,
#  'opt_ref_csls': 59.0}

# %% [markdown]
# # WGAN_GP  en_fi, lambda = 0.5, lr = adam 0.005, epochs =150

# %%
path_gp_ln_en_fi = "data/gp_ln/en_fi/log-739941.out"
line_int_ln_fi = (0, 999999)  # line interval from log file
log_ln_fi = logger(path_gp_ln_en_fi, line_int_ln_fi)
num_epochs_ln_fi = log_ln_fi.num_epochs
title_dic_ref_ln_fi = {}
title_dic_ref_ln_fi["algorithm"] = "WGAN-GP"
title_dic_ref_ln_fi["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_fi) + " epochs, 10 refinements"
save_ref_path_ln_fi = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_fi = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_fi.plot_csls_cosine_with_ref(title_dic_ref_ln_fi, save_ref_path_ln_fi, save_or_not = False)

# %%
log_ln_fi.best_res
# Out:
# {'opt_nn@1': 11.9,
#  'opt_nn@5': 28.3,
#  'opt_nn@10': 37.3,
#  'opt_csls@1': 14.5,
#  'opt_csls@5': 34.3,
#  'opt_csls@10': 42.3,
#  'opt_cos_nn': 53.7,
#  'opt_cos_csls': 52.2,
#  'opt_ref_nn@1': 22.8,
#  'opt_ref_nn@5': 47.2,
#  'opt_ref_nn@10': 56.2,
#  'opt_ref_csls@1': 26.5,
#  'opt_ref_csls@5': 52.6,
#  'opt_ref_csls@10': 62.3,
#  'opt_ref_cos_nn': 59.1,
#  'opt_ref_csls': 59.4}

# %% [markdown]
# # en hu

# %%
path_gp_ln_en_hu = "data/gp_ln/en_hu/log-770666.out"
line_int_ln_hu = (0, 999999)  # line interval from log file
log_ln_hu = logger(path_gp_ln_en_hu, line_int_ln_hu)
num_epochs_ln_hu = log_ln_fi.num_epochs
title_dic_ref_ln_hu = {}
title_dic_ref_ln_hu["algorithm"] = "WGAN-GP"
title_dic_ref_ln_hu["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_hu) + " epochs, 10 refinements"
save_ref_path_ln_hu = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_hu = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_hu.plot_csls_cosine_with_ref(title_dic_ref_ln_hu, save_ref_path_ln_hu, save_or_not = False)

# %%
log_ln_hu.best_res
# Out:
# {'opt_nn@1': 20.5,
#  'opt_nn@5': 39.0,
#  'opt_nn@10': 46.9,
#  'opt_csls@1': 23.0,
#  'opt_csls@5': 44.0,
#  'opt_csls@10': 52.5,
#  'opt_cos_nn': 55.4,
#  'opt_cos_csls': 54.4,
#  'opt_ref_nn@1': 30.6,
#  'opt_ref_nn@5': 52.4,
#  'opt_ref_nn@10': 61.3,
#  'opt_ref_csls@1': 34.0,
#  'opt_ref_csls@5': 56.4,
#  'opt_ref_csls@10': 64.9,
#  'opt_ref_cos_nn': 60.1,
#  'opt_ref_csls': 60.2}

# %% [markdown]
# # en tr

# %%
path_gp_ln_en_tr = "data/gp_ln/en_tr/log-776617.out"
line_int_ln_tr = (0, 999999)  # line interval from log file
log_ln_tr = logger(path_gp_ln_en_tr, line_int_ln_tr)
num_epochs_ln_tr = log_ln_tr.num_epochs
title_dic_ref_ln_tr = {}
title_dic_ref_ln_tr["algorithm"] = "WGAN-GP"
title_dic_ref_ln_tr["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_tr) + " epochs, 10 refinements"
save_ref_path_ln_tr = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_tr = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_tr.plot_csls_cosine_with_ref(title_dic_ref_ln_tr, save_ref_path_ln_tr, save_or_not = False)

# %%
log_ln_tr.best_res
# Out:
# {'opt_nn@1': 12.0,
#  'opt_nn@5': 25.8,
#  'opt_nn@10': 32.8,
#  'opt_csls@1': 16.2,
#  'opt_csls@5': 31.1,
#  'opt_csls@10': 38.5,
#  'opt_cos_nn': 52.5,
#  'opt_cos_csls': 50.6,
#  'opt_ref_nn@1': 26.0,
#  'opt_ref_nn@5': 45.0,
#  'opt_ref_nn@10': 52.0,
#  'opt_ref_csls@1': 29.0,
#  'opt_ref_csls@5': 48.0,
#  'opt_ref_csls@10': 56.4,
#  'opt_ref_cos_nn': 58.1,
#  'opt_ref_csls': 58.1}

# %% [markdown]
# # en pl

# %%
path_gp_ln_en_pl = "data/gp_ln/en_pl/log-777153.out"
line_int_ln_pl = (0, 999999)  # line interval from log file
log_ln_pl = logger(path_gp_ln_en_pl, line_int_ln_pl)
num_epochs_ln_pl = log_ln_pl.num_epochs
title_dic_ref_ln_pl = {}
title_dic_ref_ln_pl["algorithm"] = "WGAN-GP"
title_dic_ref_ln_pl["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_pl) + " epochs, 10 refinements"
save_ref_path_ln_pl = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_pl = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_pl.plot_csls_cosine_with_ref(title_dic_ref_ln_pl, save_ref_path_ln_pl, save_or_not = False)

# %%
log_ln_pl.best_res
# Out:
# {'opt_nn@1': 17.3,
#  'opt_nn@5': 38.7,
#  'opt_nn@10': 48.1,
#  'opt_csls@1': 19.6,
#  'opt_csls@5': 43.8,
#  'opt_csls@10': 53.8,
#  'opt_cos_nn': 53.9,
#  'opt_cos_csls': 52.6,
#  'opt_ref_nn@1': 28.1,
#  'opt_ref_nn@5': 55.7,
#  'opt_ref_nn@10': 65.4,
#  'opt_ref_csls@1': 30.1,
#  'opt_ref_csls@5': 59.6,
#  'opt_ref_csls@10': 69.0,
#  'opt_ref_cos_nn': 61.0,
#  'opt_ref_csls': 61.3}

# %% [markdown]
# # en zh

# %%
path_gp_ln_en_zh = "data/gp_ln/en_zh/log-776560.out"
line_int_ln_zh = (0, 999999)  # line interval from log file
log_ln_zh = logger(path_gp_ln_en_zh, line_int_ln_zh)
num_epochs_ln_zh = log_ln_zh.num_epochs
title_dic_ref_ln_zh = {}
title_dic_ref_ln_zh["algorithm"] = "WGAN-GP"
title_dic_ref_ln_zh["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_zh) + " epochs, 10 refinements"
save_ref_path_ln_zh = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_zh = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_zh.plot_csls_cosine_with_ref(title_dic_ref_ln_zh, save_ref_path_ln_zh, save_or_not = False)

# %%
log_ln_zh.best_res
# Out:
# {'opt_nn@1': 3.7,
#  'opt_nn@5': 8.6,
#  'opt_nn@10': 11.6,
#  'opt_csls@1': 5.7,
#  'opt_csls@5': 12.6,
#  'opt_csls@10': 16.0,
#  'opt_cos_nn': 66.6,
#  'opt_cos_csls': 64.4,
#  'opt_ref_nn@1': 0.0,
#  'opt_ref_nn@5': 0.1,
#  'opt_ref_nn@10': 0.2,
#  'opt_ref_csls@1': 0.0,
#  'opt_ref_csls@5': 0.0,
#  'opt_ref_csls@10': 0.1,
#  'opt_ref_cos_nn': 47.7,
#  'opt_ref_csls': 48.7}

# %%
[log_ln_el,log_ln_es]
# Out:
# [<utils.logger at 0x11e2204e0>, <utils.logger at 0x11f588d30>]

# %%
log_ln_el.text_lines[42].split()[-1]
# Out:
# '-1'

# %% [markdown]
# # en en

# %%
path_gp_ln_en_en = "data/gp_ln/en_en/log-777234.out"
line_int_ln_en = (0, 999999)  # line interval from log file
log_ln_en = logger(path_gp_ln_en_en, line_int_ln_en)
num_epochs_ln_en = log_ln_en.num_epochs
title_dic_ref_ln_en = {}
title_dic_ref_ln_en["algorithm"] = "WGAN-GP"
title_dic_ref_ln_en["hyper"] = "en_en, $\lambda = 0.5$, Adam, lr=0.005, " + str(num_epochs_ln_en) + " epochs, 10 refinements"
save_ref_path_ln_en = "figures/csls_cos/gp_en_en/gp_en_en_ref(csls_cos)_.pdf"
save_no_ref_path_en = "figures/csls_cos/gp_en_en/gp_en_tr_en_ref(csls_cos).pdf"
log_ln_en.plot_csls_cosine_with_ref(title_dic_ref_ln_en, save_ref_path_ln_en, save_or_not = False)

# %%
log_ln_en.best_res
# Out:
# {'opt_nn@1': 81.6,
#  'opt_nn@5': 89.1,
#  'opt_nn@10': 91.3,
#  'opt_csls@1': 83.7,
#  'opt_csls@5': 89.3,
#  'opt_csls@10': 90.8,
#  'opt_cos_nn': 58.7,
#  'opt_cos_csls': 59.2,
#  'opt_ref_nn@1': 96.4,
#  'opt_ref_nn@5': 99.2,
#  'opt_ref_nn@10': 99.3,
#  'opt_ref_csls@1': 97.9,
#  'opt_ref_csls@5': 99.4,
#  'opt_ref_csls@10': 99.4,
#  'opt_ref_cos_nn': 72.0,
#  'opt_ref_csls': 72.4}
